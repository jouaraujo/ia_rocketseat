# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', 200)
plt.style.use('seaborn-v0_8-whitegrid')

# %% [markdown]
# ## Criar DataFrames com base nos Datasets

# %%
# Carregar DataFrame de Clientes (Customers)
df_customers = pd.read_csv('datasets/churn_customers.csv')

# %%
# Mostrar os 5 primeiros registros do DataFrame
df_customers.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents
# 0  7590-VHVEG  Female              0     Yes         No
# 1  5575-GNVDE    Male              0      No         No
# 2  3668-QPYBK    Male              0      No         No
# 3  7795-CFOCW    Male              0      No         No
# 4  9237-HQITU  Female              0      No         No

# %%
# Mostrar os 5 últimos registros do DataFrame
df_customers.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents
# 7038  6840-RESVB    Male              0     Yes        Yes
# 7039  2234-XADUH  Female              0     Yes        Yes
# 7040  4801-JZAZL  Female              0     Yes        Yes
# 7041  8361-LTMKD    Male              1     Yes         No
# 7042  3186-AJIEK    Male              0      No         No

# %%
# Mostrar estrutura / schema do DataFrame
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     7043 non-null   object
#  1   gender         7043 non-null   object
#  2   SeniorCitizen  7043 non-null   int64
#  3   Partner        7043 non-null   object
#  4   Dependents     7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %%
# Carregar DataFrame de Serviços (Services)
df_services = pd.read_csv('datasets/churn_services.csv')

# %%
df_services.head()
# Out:
#    customerID PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0  7590-VHVEG           No  No phone service             DSL             No
# 1  5575-GNVDE          Yes                No             DSL            Yes
# 2  3668-QPYBK          Yes                No             DSL            Yes
# 3  7795-CFOCW           No  No phone service             DSL            Yes
# 4  9237-HQITU          Yes                No     Fiber optic             No
#
#   OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies
# 0          Yes               No          No          No              No
# 1           No              Yes          No          No              No
# 2          Yes               No          No          No              No
# 3           No              Yes         Yes          No              No
# 4           No               No          No          No              No

# %%
df_services.tail()
# Out:
#       customerID PhoneService     MultipleLines InternetService  \
# 7038  6840-RESVB          Yes               Yes             DSL
# 7039  2234-XADUH          Yes               Yes     Fiber optic
# 7040  4801-JZAZL           No  No phone service             DSL
# 7041  8361-LTMKD          Yes               Yes     Fiber optic
# 7042  3186-AJIEK          Yes                No     Fiber optic
#
#      OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 7038            Yes           No              Yes         Yes         Yes
# 7039             No          Yes              Yes          No         Yes
# 7040            Yes           No               No          No          No
# 7041             No           No               No          No          No
# 7042            Yes           No              Yes         Yes         Yes
#
#      StreamingMovies
# 7038             Yes
# 7039             Yes
# 7040              No
# 7041              No
# 7042             Yes

# %%
df_services.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   PhoneService      7043 non-null   object
#  2   MultipleLines     7043 non-null   object
#  3   InternetService   7043 non-null   object
#  4   OnlineSecurity    7043 non-null   object
#  5   OnlineBackup      7043 non-null   object
#  6   DeviceProtection  7043 non-null   object
#  7   TechSupport       7043 non-null   object
#  8   StreamingTV       7043 non-null   object
#  9   StreamingMovies   7043 non-null   object
# dtypes: object(10)
# memory usage: 550.4+ KB

# %%
# Carregar DataFrame de Contratos (Contracts)
df_contracts = pd.read_csv('datasets/churn_contracts.csv')

# %%
df_contracts.head()
# Out:
#    customerID  tenure        Contract PaperlessBilling  \
# 0  7590-VHVEG       1  Month-to-month              Yes
# 1  5575-GNVDE      34        One year               No
# 2  3668-QPYBK       2  Month-to-month              Yes
# 3  7795-CFOCW      45        One year               No
# 4  9237-HQITU       2  Month-to-month              Yes
#
#                PaymentMethod  MonthlyCharges TotalCharges Churn
# 0           Electronic check           29.85        29.85    No
# 1               Mailed check           56.95       1889.5    No
# 2               Mailed check           53.85       108.15   Yes
# 3  Bank transfer (automatic)           42.30      1840.75    No
# 4           Electronic check           70.70       151.65   Yes

# %%
df_contracts.tail()
# Out:
#       customerID  tenure        Contract PaperlessBilling  \
# 7038  6840-RESVB      24        One year              Yes
# 7039  2234-XADUH      72        One year              Yes
# 7040  4801-JZAZL      11  Month-to-month              Yes
# 7041  8361-LTMKD       4  Month-to-month              Yes
# 7042  3186-AJIEK      66        Two year              Yes
#
#                   PaymentMethod  MonthlyCharges TotalCharges Churn
# 7038               Mailed check           84.80       1990.5    No
# 7039    Credit card (automatic)          103.20       7362.9    No
# 7040           Electronic check           29.60       346.45    No
# 7041               Mailed check           74.40        306.6   Yes
# 7042  Bank transfer (automatic)          105.65       6844.5    No

# %%
df_contracts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   tenure            7043 non-null   int64
#  2   Contract          7043 non-null   object
#  3   PaperlessBilling  7043 non-null   object
#  4   PaymentMethod     7043 non-null   object
#  5   MonthlyCharges    7043 non-null   float64
#  6   TotalCharges      7043 non-null   object
#  7   Churn             7043 non-null   object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 440.3+ KB

# %% [markdown]
# ## Transformação de Dados

# %%
# Transformar coluna TotalCharges de String para Float - Abordagem 1 com astype
# df_contracts.TotalCharges = df_contracts.TotalCharges.astype(float) # vai dar erro

# %%
# Transformar coluna TotalCharges de String para Float - Abordagem 2 (to_numeric)
# df_contracts.TotalCharges = pd.to_numeric(df_contracts.TotalCharges) # vai dar erro

# %%
# Transformar coluna TotalCharges de String para Float - Abordagem 3 (to_numeric com coerce)
df_contracts.TotalCharges = pd.to_numeric(df_contracts.TotalCharges, errors='coerce')

# %%
# Mostrar estrutura / schema do DataFrame
df_contracts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   tenure            7043 non-null   int64
#  2   Contract          7043 non-null   object
#  3   PaperlessBilling  7043 non-null   object
#  4   PaymentMethod     7043 non-null   object
#  5   MonthlyCharges    7043 non-null   float64
#  6   TotalCharges      7032 non-null   float64
#  7   Churn             7043 non-null   object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 440.3+ KB

# %% [markdown]
# Após a transformação da coluna TotalCharges do Dataframe Contracts, a coluna passou a ter 11 valores ausentes (missing values)

# %% [markdown]
# ## Renomear Colunas

# %%
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     7043 non-null   object
#  1   gender         7043 non-null   object
#  2   SeniorCitizen  7043 non-null   int64
#  3   Partner        7043 non-null   object
#  4   Dependents     7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %%
# Renomear coluna no Dataframe, usando rename e dicionário
df_customers.rename(columns={'SeniorCitizen' : 'Above65yo'})
# Out:
#       customerID  gender  Above65yo Partner Dependents
# 0     7590-VHVEG  Female          0     Yes         No
# 1     5575-GNVDE    Male          0      No         No
# 2     3668-QPYBK    Male          0      No         No
# 3     7795-CFOCW    Male          0      No         No
# 4     9237-HQITU  Female          0      No         No
# ...          ...     ...        ...     ...        ...
# 7038  6840-RESVB    Male          0     Yes        Yes
# 7039  2234-XADUH  Female          0     Yes        Yes
# 7040  4801-JZAZL  Female          0     Yes        Yes
# 7041  8361-LTMKD    Male          1     Yes         No
# 7042  3186-AJIEK    Male          0      No         No
#
# [7043 rows x 5 columns]

# %%
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     7043 non-null   object
#  1   gender         7043 non-null   object
#  2   SeniorCitizen  7043 non-null   int64
#  3   Partner        7043 non-null   object
#  4   Dependents     7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %%
# Criar um Dataframe novo com base nas colunas renomeadas
df_customers_renamed = df_customers.rename(columns={'SeniorCitizen' : 'Above65yo'})

# %%
# Mostrar estrutura do Dataframe novo
df_customers_renamed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7043 non-null   object
#  1   gender      7043 non-null   object
#  2   Above65yo   7043 non-null   int64
#  3   Partner     7043 non-null   object
#  4   Dependents  7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %%
# Aplicar o resultado do rename no próprio Dataframe
# Criar um Dataframe novo com base nas colunas renomeadas
df_customers.rename(columns={'SeniorCitizen' : 'Above65yo'}, inplace=True)

# %%
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7043 non-null   object
#  1   gender      7043 non-null   object
#  2   Above65yo   7043 non-null   int64
#  3   Partner     7043 non-null   object
#  4   Dependents  7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %%
# Rename usando LIsta - Modificar todos os nomes e colunas
df_customers.columns = ['IDCliente', 'Genero', 'Mais65anos', 'TemParceiro', 'TemDependentes']

# %%
# Mostrar estrutura
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   IDCliente       7043 non-null   object
#  1   Genero          7043 non-null   object
#  2   Mais65anos      7043 non-null   int64
#  3   TemParceiro     7043 non-null   object
#  4   TemDependentes  7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %% [markdown]
# ## Unificar Dataframes de Customers, Services e Contracts

# %%
# Contar quantidades de registros por Dataframe
len(df_customers)
# Out:
# 7043

# %%
len(df_services)
# Out:
# 7043

# %%
len(df_contracts)
# Out:
# 7043

# %%
# Renomear colunas
df_services.rename(columns={'customerID': 'IDCliente'}, inplace=True)

# %%
# Unificar Dataframe de Customers com Services, criando um terceiro Dataframe
df_temp = df_customers.merge(df_services, on=['IDCliente'])

# %%
# Mostrar estrutura dataframe temp
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   IDCliente         7043 non-null   object
#  1   Genero            7043 non-null   object
#  2   Mais65anos        7043 non-null   int64
#  3   TemParceiro       7043 non-null   object
#  4   TemDependentes    7043 non-null   object
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
# dtypes: int64(1), object(13)
# memory usage: 770.5+ KB

# %%
df_temp.head()
# Out:
#     IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 0  7590-VHVEG  Female           0         Yes             No           No
# 1  5575-GNVDE    Male           0          No             No          Yes
# 2  3668-QPYBK    Male           0          No             No          Yes
# 3  7795-CFOCW    Male           0          No             No           No
# 4  9237-HQITU  Female           0          No             No          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies
# 0               No          No          No              No
# 1              Yes          No          No              No
# 2               No          No          No              No
# 3              Yes         Yes          No              No
# 4               No          No          No              No

# %%
# Unificar df_temp com Contracts, usando colunas de junção com nomes distintos
df_churn_temp = df_temp.merge(df_contracts, left_on=['IDCliente'], right_on=['customerID'])

# %%
df_churn_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   IDCliente         7043 non-null   object
#  1   Genero            7043 non-null   object
#  2   Mais65anos        7043 non-null   int64
#  3   TemParceiro       7043 non-null   object
#  4   TemDependentes    7043 non-null   object
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  customerID        7043 non-null   object
#  15  tenure            7043 non-null   int64
#  16  Contract          7043 non-null   object
#  17  PaperlessBilling  7043 non-null   object
#  18  PaymentMethod     7043 non-null   object
#  19  MonthlyCharges    7043 non-null   float64
#  20  TotalCharges      7032 non-null   float64
#  21  Churn             7043 non-null   object
# dtypes: float64(2), int64(2), object(18)
# memory usage: 1.2+ MB

# %%
# Unificar os 3 dataframes ao mesmo tempo, com colunas com nomes diferentes
df_churn = df_customers.merge(df_services, on=['IDCliente']) \
                       .merge(df_contracts, left_on=['IDCliente'], right_on=['customerID'])

# %%
df_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   IDCliente         7043 non-null   object
#  1   Genero            7043 non-null   object
#  2   Mais65anos        7043 non-null   int64
#  3   TemParceiro       7043 non-null   object
#  4   TemDependentes    7043 non-null   object
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  customerID        7043 non-null   object
#  15  tenure            7043 non-null   int64
#  16  Contract          7043 non-null   object
#  17  PaperlessBilling  7043 non-null   object
#  18  PaymentMethod     7043 non-null   object
#  19  MonthlyCharges    7043 non-null   float64
#  20  TotalCharges      7032 non-null   float64
#  21  Churn             7043 non-null   object
# dtypes: float64(2), int64(2), object(18)
# memory usage: 1.2+ MB

# %%
# Removendo coluna de um dataframe
df_churn.drop(['customerID'], axis=1, inplace=True)

# %%
df_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   IDCliente         7043 non-null   object
#  1   Genero            7043 non-null   object
#  2   Mais65anos        7043 non-null   int64
#  3   TemParceiro       7043 non-null   object
#  4   TemDependentes    7043 non-null   object
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  tenure            7043 non-null   int64
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7032 non-null   float64
#  20  Churn             7043 non-null   object
# dtypes: float64(2), int64(2), object(17)
# memory usage: 1.1+ MB

# %% [markdown]
# ## Detecção de Valores ausentes

# %%
# Detectar valores ausentes em todas as colunas de um Dataframe
df_churn.isna().sum()
# Out:
# IDCliente            0
# Genero               0
# Mais65anos           0
# TemParceiro          0
# TemDependentes       0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# tenure               0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
df_churn['TotalCharges'].isna().sum()
# Out:
# 11

# %%
# Quantas linhas tem pelo menos 1 coluna com valor ausente
df_churn[df_churn.isna().any(axis=1)]
# Out:
#        IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 488   4472-LVYGI  Female           0         Yes            Yes           No
# 753   3115-CZMZD    Male           0          No            Yes          Yes
# 936   5709-LVOEQ  Female           0         Yes            Yes          Yes
# 1082  4367-NUYAO    Male           0         Yes            Yes          Yes
# 1340  1371-DWPAZ  Female           0         Yes            Yes           No
# 3331  7644-OMVMY    Male           0         Yes            Yes          Yes
# 3826  3213-VVOLG    Male           0         Yes            Yes          Yes
# 4380  2520-SGTTA  Female           0         Yes            Yes          Yes
# 5218  2923-ARZLG    Male           0         Yes            Yes          Yes
# 6670  4075-WKNIU  Female           0         Yes            Yes          Yes
# 6754  2775-SEFEE    Male           0          No            Yes          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# 753                 No              No  No internet service
# 936                 No             DSL                  Yes
# 1082               Yes              No  No internet service
# 1340  No phone service             DSL                  Yes
# 3331                No              No  No internet service
# 3826               Yes              No  No internet service
# 4380                No              No  No internet service
# 5218                No              No  No internet service
# 6670               Yes             DSL                   No
# 6754               Yes             DSL                  Yes
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 488                    No                  Yes                  Yes
# 753   No internet service  No internet service  No internet service
# 936                   Yes                  Yes                   No
# 1082  No internet service  No internet service  No internet service
# 1340                  Yes                  Yes                  Yes
# 3331  No internet service  No internet service  No internet service
# 3826  No internet service  No internet service  No internet service
# 4380  No internet service  No internet service  No internet service
# 5218  No internet service  No internet service  No internet service
# 6670                  Yes                  Yes                  Yes
# 6754                  Yes                   No                  Yes
#
#               StreamingTV      StreamingMovies  tenure  Contract  \
# 488                   Yes                   No       0  Two year
# 753   No internet service  No internet service       0  Two year
# 936                   Yes                  Yes       0  Two year
# 1082  No internet service  No internet service       0  Two year
# 1340                  Yes                   No       0  Two year
# 3331  No internet service  No internet service       0  Two year
# 3826  No internet service  No internet service       0  Two year
# 4380  No internet service  No internet service       0  Two year
# 5218  No internet service  No internet service       0  One year
# 6670                  Yes                   No       0  Two year
# 6754                   No                   No       0  Two year
#
#      PaperlessBilling              PaymentMethod  MonthlyCharges  \
# 488               Yes  Bank transfer (automatic)           52.55
# 753                No               Mailed check           20.25
# 936                No               Mailed check           80.85
# 1082               No               Mailed check           25.75
# 1340               No    Credit card (automatic)           56.05
# 3331               No               Mailed check           19.85
# 3826               No               Mailed check           25.35
# 4380               No               Mailed check           20.00
# 5218              Yes               Mailed check           19.70
# 6670               No               Mailed check           73.35
# 6754              Yes  Bank transfer (automatic)           61.90
#
#       TotalCharges Churn
# 488            NaN    No
# 753            NaN    No
# 936            NaN    No
# 1082           NaN    No
# 1340           NaN    No
# 3331           NaN    No
# 3826           NaN    No
# 4380           NaN    No
# 5218           NaN    No
# 6670           NaN    No
# 6754           NaN    No

# %%
# Quantas coluans têm pelo menos 1 valor ausente
df_churn.isna().any(axis=0).sum()
# Out:
# 1

# %% [markdown]
# ## Remover valores ausentes

# %%
# Remover de forma direta e específica a coluna que possui valores ausentes
df_churn.drop(columns=['TotalCharges'], axis=1)
# Out:
#        IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# 1                   No             DSL            Yes           No
# 2                   No             DSL            Yes          Yes
# 3     No phone service             DSL            Yes           No
# 4                   No     Fiber optic             No           No
# ...                ...             ...            ...          ...
# 7038               Yes             DSL            Yes           No
# 7039               Yes     Fiber optic             No          Yes
# 7040  No phone service             DSL            Yes           No
# 7041               Yes     Fiber optic             No           No
# 7042                No     Fiber optic            Yes           No
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies  tenure  \
# 0                  No          No          No              No       1
# 1                 Yes          No          No              No      34
# 2                  No          No          No              No       2
# 3                 Yes         Yes          No              No      45
# 4                  No          No          No              No       2
# ...               ...         ...         ...             ...     ...
# 7038              Yes         Yes         Yes             Yes      24
# 7039              Yes          No         Yes             Yes      72
# 7040               No          No          No              No      11
# 7041               No          No          No              No       4
# 7042              Yes         Yes         Yes             Yes      66
#
#             Contract PaperlessBilling              PaymentMethod  \
# 0     Month-to-month              Yes           Electronic check
# 1           One year               No               Mailed check
# 2     Month-to-month              Yes               Mailed check
# 3           One year               No  Bank transfer (automatic)
# 4     Month-to-month              Yes           Electronic check
# ...              ...              ...                        ...
# 7038        One year              Yes               Mailed check
# 7039        One year              Yes    Credit card (automatic)
# 7040  Month-to-month              Yes           Electronic check
# 7041  Month-to-month              Yes               Mailed check
# 7042        Two year              Yes  Bank transfer (automatic)
#
#       MonthlyCharges Churn
# 0              29.85    No
# 1              56.95    No
# 2              53.85   Yes
# 3              42.30    No
# 4              70.70   Yes
# ...              ...   ...
# 7038           84.80    No
# 7039          103.20    No
# 7040           29.60    No
# 7041           74.40   Yes
# 7042          105.65    No
#
# [7043 rows x 20 columns]

# %%
# Remover colunas com valores ausentes
df_churn.dropna(axis=1)
# Out:
#        IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# 1                   No             DSL            Yes           No
# 2                   No             DSL            Yes          Yes
# 3     No phone service             DSL            Yes           No
# 4                   No     Fiber optic             No           No
# ...                ...             ...            ...          ...
# 7038               Yes             DSL            Yes           No
# 7039               Yes     Fiber optic             No          Yes
# 7040  No phone service             DSL            Yes           No
# 7041               Yes     Fiber optic             No           No
# 7042                No     Fiber optic            Yes           No
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies  tenure  \
# 0                  No          No          No              No       1
# 1                 Yes          No          No              No      34
# 2                  No          No          No              No       2
# 3                 Yes         Yes          No              No      45
# 4                  No          No          No              No       2
# ...               ...         ...         ...             ...     ...
# 7038              Yes         Yes         Yes             Yes      24
# 7039              Yes          No         Yes             Yes      72
# 7040               No          No          No              No      11
# 7041               No          No          No              No       4
# 7042              Yes         Yes         Yes             Yes      66
#
#             Contract PaperlessBilling              PaymentMethod  \
# 0     Month-to-month              Yes           Electronic check
# 1           One year               No               Mailed check
# 2     Month-to-month              Yes               Mailed check
# 3           One year               No  Bank transfer (automatic)
# 4     Month-to-month              Yes           Electronic check
# ...              ...              ...                        ...
# 7038        One year              Yes               Mailed check
# 7039        One year              Yes    Credit card (automatic)
# 7040  Month-to-month              Yes           Electronic check
# 7041  Month-to-month              Yes               Mailed check
# 7042        Two year              Yes  Bank transfer (automatic)
#
#       MonthlyCharges Churn
# 0              29.85    No
# 1              56.95    No
# 2              53.85   Yes
# 3              42.30    No
# 4              70.70   Yes
# ...              ...   ...
# 7038           84.80    No
# 7039          103.20    No
# 7040           29.60    No
# 7041           74.40   Yes
# 7042          105.65    No
#
# [7043 rows x 20 columns]

# %%
# Remover colunas onde todos os valores são ausentes
df_churn.dropna(axis=1, how='all')
# Out:
#        IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# 1                   No             DSL            Yes           No
# 2                   No             DSL            Yes          Yes
# 3     No phone service             DSL            Yes           No
# 4                   No     Fiber optic             No           No
# ...                ...             ...            ...          ...
# 7038               Yes             DSL            Yes           No
# 7039               Yes     Fiber optic             No          Yes
# 7040  No phone service             DSL            Yes           No
# 7041               Yes     Fiber optic             No           No
# 7042                No     Fiber optic            Yes           No
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies  tenure  \
# 0                  No          No          No              No       1
# 1                 Yes          No          No              No      34
# 2                  No          No          No              No       2
# 3                 Yes         Yes          No              No      45
# 4                  No          No          No              No       2
# ...               ...         ...         ...             ...     ...
# 7038              Yes         Yes         Yes             Yes      24
# 7039              Yes          No         Yes             Yes      72
# 7040               No          No          No              No      11
# 7041               No          No          No              No       4
# 7042              Yes         Yes         Yes             Yes      66
#
#             Contract PaperlessBilling              PaymentMethod  \
# 0     Month-to-month              Yes           Electronic check
# 1           One year               No               Mailed check
# 2     Month-to-month              Yes               Mailed check
# 3           One year               No  Bank transfer (automatic)
# 4     Month-to-month              Yes           Electronic check
# ...              ...              ...                        ...
# 7038        One year              Yes               Mailed check
# 7039        One year              Yes    Credit card (automatic)
# 7040  Month-to-month              Yes           Electronic check
# 7041  Month-to-month              Yes               Mailed check
# 7042        Two year              Yes  Bank transfer (automatic)
#
#       MonthlyCharges  TotalCharges Churn
# 0              29.85         29.85    No
# 1              56.95       1889.50    No
# 2              53.85        108.15   Yes
# 3              42.30       1840.75    No
# 4              70.70        151.65   Yes
# ...              ...           ...   ...
# 7038           84.80       1990.50    No
# 7039          103.20       7362.90    No
# 7040           29.60        346.45    No
# 7041           74.40        306.60   Yes
# 7042          105.65       6844.50    No
#
# [7043 rows x 21 columns]

# %%
# Remover as linhas com valores ausentes
df_churn.dropna(axis=0)
# Out:
#        IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# 1                   No             DSL            Yes           No
# 2                   No             DSL            Yes          Yes
# 3     No phone service             DSL            Yes           No
# 4                   No     Fiber optic             No           No
# ...                ...             ...            ...          ...
# 7038               Yes             DSL            Yes           No
# 7039               Yes     Fiber optic             No          Yes
# 7040  No phone service             DSL            Yes           No
# 7041               Yes     Fiber optic             No           No
# 7042                No     Fiber optic            Yes           No
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies  tenure  \
# 0                  No          No          No              No       1
# 1                 Yes          No          No              No      34
# 2                  No          No          No              No       2
# 3                 Yes         Yes          No              No      45
# 4                  No          No          No              No       2
# ...               ...         ...         ...             ...     ...
# 7038              Yes         Yes         Yes             Yes      24
# 7039              Yes          No         Yes             Yes      72
# 7040               No          No          No              No      11
# 7041               No          No          No              No       4
# 7042              Yes         Yes         Yes             Yes      66
#
#             Contract PaperlessBilling              PaymentMethod  \
# 0     Month-to-month              Yes           Electronic check
# 1           One year               No               Mailed check
# 2     Month-to-month              Yes               Mailed check
# 3           One year               No  Bank transfer (automatic)
# 4     Month-to-month              Yes           Electronic check
# ...              ...              ...                        ...
# 7038        One year              Yes               Mailed check
# 7039        One year              Yes    Credit card (automatic)
# 7040  Month-to-month              Yes           Electronic check
# 7041  Month-to-month              Yes               Mailed check
# 7042        Two year              Yes  Bank transfer (automatic)
#
#       MonthlyCharges  TotalCharges Churn
# 0              29.85         29.85    No
# 1              56.95       1889.50    No
# 2              53.85        108.15   Yes
# 3              42.30       1840.75    No
# 4              70.70        151.65   Yes
# ...              ...           ...   ...
# 7038           84.80       1990.50    No
# 7039          103.20       7362.90    No
# 7040           29.60        346.45    No
# 7041           74.40        306.60   Yes
# 7042          105.65       6844.50    No
#
# [7032 rows x 21 columns]

# %%
# Remover linhas com todos os valores ausentes
df_churn.dropna(axis=0, how='all')
# Out:
#        IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# 1                   No             DSL            Yes           No
# 2                   No             DSL            Yes          Yes
# 3     No phone service             DSL            Yes           No
# 4                   No     Fiber optic             No           No
# ...                ...             ...            ...          ...
# 7038               Yes             DSL            Yes           No
# 7039               Yes     Fiber optic             No          Yes
# 7040  No phone service             DSL            Yes           No
# 7041               Yes     Fiber optic             No           No
# 7042                No     Fiber optic            Yes           No
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies  tenure  \
# 0                  No          No          No              No       1
# 1                 Yes          No          No              No      34
# 2                  No          No          No              No       2
# 3                 Yes         Yes          No              No      45
# 4                  No          No          No              No       2
# ...               ...         ...         ...             ...     ...
# 7038              Yes         Yes         Yes             Yes      24
# 7039              Yes          No         Yes             Yes      72
# 7040               No          No          No              No      11
# 7041               No          No          No              No       4
# 7042              Yes         Yes         Yes             Yes      66
#
#             Contract PaperlessBilling              PaymentMethod  \
# 0     Month-to-month              Yes           Electronic check
# 1           One year               No               Mailed check
# 2     Month-to-month              Yes               Mailed check
# 3           One year               No  Bank transfer (automatic)
# 4     Month-to-month              Yes           Electronic check
# ...              ...              ...                        ...
# 7038        One year              Yes               Mailed check
# 7039        One year              Yes    Credit card (automatic)
# 7040  Month-to-month              Yes           Electronic check
# 7041  Month-to-month              Yes               Mailed check
# 7042        Two year              Yes  Bank transfer (automatic)
#
#       MonthlyCharges  TotalCharges Churn
# 0              29.85         29.85    No
# 1              56.95       1889.50    No
# 2              53.85        108.15   Yes
# 3              42.30       1840.75    No
# 4              70.70        151.65   Yes
# ...              ...           ...   ...
# 7038           84.80       1990.50    No
# 7039          103.20       7362.90    No
# 7040           29.60        346.45    No
# 7041           74.40        306.60   Yes
# 7042          105.65       6844.50    No
#
# [7043 rows x 21 columns]

# %% [markdown]
# ## Imputação de Valores Ausentes

# %%
# Preencher todos os valores ausentes com 0
df_churn.fillna(0)
# Out:
#        IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# 1                   No             DSL            Yes           No
# 2                   No             DSL            Yes          Yes
# 3     No phone service             DSL            Yes           No
# 4                   No     Fiber optic             No           No
# ...                ...             ...            ...          ...
# 7038               Yes             DSL            Yes           No
# 7039               Yes     Fiber optic             No          Yes
# 7040  No phone service             DSL            Yes           No
# 7041               Yes     Fiber optic             No           No
# 7042                No     Fiber optic            Yes           No
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies  tenure  \
# 0                  No          No          No              No       1
# 1                 Yes          No          No              No      34
# 2                  No          No          No              No       2
# 3                 Yes         Yes          No              No      45
# 4                  No          No          No              No       2
# ...               ...         ...         ...             ...     ...
# 7038              Yes         Yes         Yes             Yes      24
# 7039              Yes          No         Yes             Yes      72
# 7040               No          No          No              No      11
# 7041               No          No          No              No       4
# 7042              Yes         Yes         Yes             Yes      66
#
#             Contract PaperlessBilling              PaymentMethod  \
# 0     Month-to-month              Yes           Electronic check
# 1           One year               No               Mailed check
# 2     Month-to-month              Yes               Mailed check
# 3           One year               No  Bank transfer (automatic)
# 4     Month-to-month              Yes           Electronic check
# ...              ...              ...                        ...
# 7038        One year              Yes               Mailed check
# 7039        One year              Yes    Credit card (automatic)
# 7040  Month-to-month              Yes           Electronic check
# 7041  Month-to-month              Yes               Mailed check
# 7042        Two year              Yes  Bank transfer (automatic)
#
#       MonthlyCharges  TotalCharges Churn
# 0              29.85         29.85    No
# 1              56.95       1889.50    No
# 2              53.85        108.15   Yes
# 3              42.30       1840.75    No
# 4              70.70        151.65   Yes
# ...              ...           ...   ...
# 7038           84.80       1990.50    No
# 7039          103.20       7362.90    No
# 7040           29.60        346.45    No
# 7041           74.40        306.60   Yes
# 7042          105.65       6844.50    No
#
# [7043 rows x 21 columns]

# %%
# Preencher valores padrão conforme a coluna
df_churn.fillna(value={'TotalCharges': 0, 'Genero': 'Não Declarado'})
# Out:
#        IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# 1                   No             DSL            Yes           No
# 2                   No             DSL            Yes          Yes
# 3     No phone service             DSL            Yes           No
# 4                   No     Fiber optic             No           No
# ...                ...             ...            ...          ...
# 7038               Yes             DSL            Yes           No
# 7039               Yes     Fiber optic             No          Yes
# 7040  No phone service             DSL            Yes           No
# 7041               Yes     Fiber optic             No           No
# 7042                No     Fiber optic            Yes           No
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies  tenure  \
# 0                  No          No          No              No       1
# 1                 Yes          No          No              No      34
# 2                  No          No          No              No       2
# 3                 Yes         Yes          No              No      45
# 4                  No          No          No              No       2
# ...               ...         ...         ...             ...     ...
# 7038              Yes         Yes         Yes             Yes      24
# 7039              Yes          No         Yes             Yes      72
# 7040               No          No          No              No      11
# 7041               No          No          No              No       4
# 7042              Yes         Yes         Yes             Yes      66
#
#             Contract PaperlessBilling              PaymentMethod  \
# 0     Month-to-month              Yes           Electronic check
# 1           One year               No               Mailed check
# 2     Month-to-month              Yes               Mailed check
# 3           One year               No  Bank transfer (automatic)
# 4     Month-to-month              Yes           Electronic check
# ...              ...              ...                        ...
# 7038        One year              Yes               Mailed check
# 7039        One year              Yes    Credit card (automatic)
# 7040  Month-to-month              Yes           Electronic check
# 7041  Month-to-month              Yes               Mailed check
# 7042        Two year              Yes  Bank transfer (automatic)
#
#       MonthlyCharges  TotalCharges Churn
# 0              29.85         29.85    No
# 1              56.95       1889.50    No
# 2              53.85        108.15   Yes
# 3              42.30       1840.75    No
# 4              70.70        151.65   Yes
# ...              ...           ...   ...
# 7038           84.80       1990.50    No
# 7039          103.20       7362.90    No
# 7040           29.60        346.45    No
# 7041           74.40        306.60   Yes
# 7042          105.65       6844.50    No
#
# [7043 rows x 21 columns]

# %%
# Preencher todos os valores ausentes de uma coluna com a média
media_TotalCharges = df_churn.TotalCharges.mean()

# %%
media_TotalCharges
# Out:
# 2283.3004408418656

# %%
df_churn.fillna(value={'TotalCharges' : media_TotalCharges})
# Out:
#        IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# 1                   No             DSL            Yes           No
# 2                   No             DSL            Yes          Yes
# 3     No phone service             DSL            Yes           No
# 4                   No     Fiber optic             No           No
# ...                ...             ...            ...          ...
# 7038               Yes             DSL            Yes           No
# 7039               Yes     Fiber optic             No          Yes
# 7040  No phone service             DSL            Yes           No
# 7041               Yes     Fiber optic             No           No
# 7042                No     Fiber optic            Yes           No
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies  tenure  \
# 0                  No          No          No              No       1
# 1                 Yes          No          No              No      34
# 2                  No          No          No              No       2
# 3                 Yes         Yes          No              No      45
# 4                  No          No          No              No       2
# ...               ...         ...         ...             ...     ...
# 7038              Yes         Yes         Yes             Yes      24
# 7039              Yes          No         Yes             Yes      72
# 7040               No          No          No              No      11
# 7041               No          No          No              No       4
# 7042              Yes         Yes         Yes             Yes      66
#
#             Contract PaperlessBilling              PaymentMethod  \
# 0     Month-to-month              Yes           Electronic check
# 1           One year               No               Mailed check
# 2     Month-to-month              Yes               Mailed check
# 3           One year               No  Bank transfer (automatic)
# 4     Month-to-month              Yes           Electronic check
# ...              ...              ...                        ...
# 7038        One year              Yes               Mailed check
# 7039        One year              Yes    Credit card (automatic)
# 7040  Month-to-month              Yes           Electronic check
# 7041  Month-to-month              Yes               Mailed check
# 7042        Two year              Yes  Bank transfer (automatic)
#
#       MonthlyCharges  TotalCharges Churn
# 0              29.85         29.85    No
# 1              56.95       1889.50    No
# 2              53.85        108.15   Yes
# 3              42.30       1840.75    No
# 4              70.70        151.65   Yes
# ...              ...           ...   ...
# 7038           84.80       1990.50    No
# 7039          103.20       7362.90    No
# 7040           29.60        346.45    No
# 7041           74.40        306.60   Yes
# 7042          105.65       6844.50    No
#
# [7043 rows x 21 columns]

# %% [markdown]
# ## Análise Univariada

# %% [markdown]
# - A faixa etária do cliente tem uma forte associação com o churn
# - Um cliente com menos de 6 meses de contrato é mais propenso ao churn
# - Cliente com contrato mensal é mais propenso ao churn

# %%
# Como identificar valores possíveis (únicos) numa variável do Dataframe
df_churn.Churn.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
# Contar clientes usando a variável Churn com referência
df_churn.Churn.value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
# Como é a distribuição de clientes (percentual) que abandonaram ou continuam ativos
df_churn.Churn.value_counts(normalize=True)
# Out:
# Churn
# No     0.73463
# Yes    0.26537
# Name: proportion, dtype: float64

# %%
# Plot distribuição do Churn (Quantidade)
ax = df_churn.Churn.value_counts().plot.bar(color=('#ff7676', '#cbbbf4'))

ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '5174'), Text(0, 0, '1869')]

# %%
# Plot distribuição Churn (percentual)
ax = df_churn.Churn.value_counts(normalize=True).plot.bar(color=['#9cb076', '#5fb03d'])

ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '0.73463'), Text(0, 0, '0.26537')]

# %%
# Quais são os tipos de contratos
df_churn.Contract.unique()
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %%
# Plot distribuição do Contract (Quantidade)
ax = df_churn.Contract.value_counts().plot.bar(color=['#9cb076', '#5fb03d', '#cbbbf4'])
ax.bar_label(ax.containers[0])
plt.xticks(rotation=360)
plt.show()

# %%
# Plot distribuição do Contract (Percentual)
ax = df_churn.Contract.value_counts(normalize=True).plot.bar(color=['#9cb076', '#5fb03d', '#cbbbf4'])
ax.bar_label(ax.containers[0])
plt.xticks(rotation=360)
plt.show()

# %%
# Histograma do Tempo de Contrato
df_churn.tenure.plot.hist()
plt.show()

# %% [markdown]
# - A variável tempo de contrato (tenure) não apresenta visualmente uma distribuição normal
# - A grande parte dos valores se concentram nos extremos, ou seja contratos com poucos meses de ativação e contratos longos, acima aproximadamente dos 65 meses.

# %%
# Histograma do Monthly Charges
df_churn.MonthlyCharges.plot.hist()
plt.show()

# %%
# Medidades de Posição - Média tempo de contrato
df_churn.tenure.mean()
# Out:
# 32.37114865824223

# %%
# Medidas de Posição - Mediana tempo de contrato
df_churn.tenure.median()
# Out:
# 29.0

# %%
# Medidas de Posição - Moda tempo de contrato
df_churn.tenure.mode()
# Out:
# 0    1
# Name: tenure, dtype: int64

# %%
# Medidas de Dispersão - Desvio Padrão tempo de contrato
df_churn.tenure.std()
# Out:
# 24.55948102309446

# %%
# Medidas de Dispersão - Coeficiente de Variação tempo de contrato
df_churn.tenure.std() / df_churn.tenure.mean() * 100
# Out:
# 75.86842617906674

# %%
# Quantos clientes possuem 1 mês de contrato - Filtro
len(df_churn[(df_churn.tenure == 1)])
# Out:
# 613

# %%
# Quanto os clientes de 1 mês representam percentualmente
len(df_churn[(df_churn.tenure == 1)]) / len(df_churn) * 100
# Out:
# 8.70367741019452

# %%
# Quantos clientes possuem entre 1 e 6 meses de contrato
len(df_churn[(df_churn.tenure >= 1) & (df_churn.tenure <= 6)])
# Out:
# 1470

# %%
# Quantos homens possuem até 6 meses de contrato
len(df_churn[(df_churn.Genero == 'Male') & (df_churn.tenure <= 6)])
# Out:
# 746

# %%
# Apresentar a quantidade de clientes por tempo de contrato - Agrupamento com sumarização
df_churn.groupby(['tenure'])['tenure'].count().sort_values(ascending=False)
# Out:
# tenure
# 1     613
# 72    362
# 2     238
# 3     200
# 4     176
#      ...
# 28     57
# 39     56
# 44     51
# 36     50
# 0      11
# Name: tenure, Length: 73, dtype: int64

# %%
# Apresentar a quantidade de clientes por tempo de contrato - Agrupamento com sumarização - Em um plot
df_churn.groupby(['tenure'])['tenure'].count().sort_values().plot.barh(color=['#5fb03d'], figsize=(20,20))
plt.show()

# %% [markdown]
# ## Análise Bivariada

# %%
# Hipótese: Clientes com Contrato do Tipo Mensal são mais propensos ao Churn
# Construir Tabela de Contingência entre Tipo de Contrato e Churn - Quantidade
pd.crosstab(df_churn.Churn, df_churn.Contract, margins=True, margins_name='Total')
# Out:
# Contract  Month-to-month  One year  Two year  Total
# Churn
# No                  2220      1307      1647   5174
# Yes                 1655       166        48   1869
# Total               3875      1473      1695   7043

# %%
# Construir Tabela de Contingência entre Tipo de Contrato e Churn - Proporção
pd.crosstab(df_churn.Churn, df_churn.Contract, margins=True,
             margins_name='Total', normalize='index') * 100
# Out:
# Contract  Month-to-month   One year   Two year
# Churn
# No             42.906842  25.260920  31.832238
# Yes            88.550027   8.881755   2.568218
# Total          55.019168  20.914383  24.066449

# %% [markdown]
# Considerando o publico total, os clientes de contrato mensal representam  55%. Porém, se considerarmos apenas os clientes que abandonaram o serviço, 88%
# tinham contrato mensal. Desta forma podemos afirmar que há uma correlação  entre o tipo de contrato mensal e o abandono.

# %%
# Avaliar a correlação entre duas variáveis categóricas (qualitativas)

# Executar um teste de hipótese chamado Chi-Square ou Qui-Quadrado  de Pearson
# Num teste de hipótese, duas hipóteses são formuladas:
# H0 (Hipótese Nula): as duas variáveis são independentes
# H1 (Hipótese Alternativa): as duas variáveis não são independentes

# O teste serve para confirmar ou recusar a hipótese nula (H0)
# Quando a probabilidade de observarmos H0 é inferior a 0.05 (p-value),
# recusamos a hipótese nula e seguimos com a alternativa

# %%
# Gerar um DF da Crosstab (sem totais)
df_crosstab_churn_contract = pd.crosstab(df_churn.Churn, df_churn.Contract)

# %%
# Calcular os Scores e P-Values
from scipy.stats import chi2_contingency

# %%
# Tupla = Lista imutável
chi_scores_churn_contract = chi2_contingency(df_crosstab_churn_contract)

# %%
chi_scores_churn_contract
# Out:
# Chi2ContingencyResult(statistic=1184.5965720837926, pvalue=5.863038300673391e-258, dof=2, expected_freq=array([[2846.69175067, 1082.11018032, 1245.198069  ],
#        [1028.30824933,  390.88981968,  449.801931  ]]))

# %%
scores_churn_contract = pd.Series(chi_scores_churn_contract[0])

# %%
pvalues_churn_contract = pd.Series(chi_scores_churn_contract[1])

# %%
# Apresentar numeros com decimais sem a notação científica
pd.set_option('display.float_format', lambda x: '{:.15f}'.format(x))

# %%
# Criar um Dataframe com os resultados
df_chi_scores_churn_contract = pd.DataFrame(
    {
        'Qui2' : scores_churn_contract, 
        'p-value' : pvalues_churn_contract
    }
)

# %%
# Analisar Scores e P-Values
df_chi_scores_churn_contract
# Out:
#                   Qui2           p-value
# 0 1184.596572083792580 0.000000000000000

# %% [markdown]
# Conforme Teste Estatístico (Chi-Square), o P-Value <= 0.05, desta forma rejeitamos a hipótese nula, ou seja, as variáveis não são independentes. Pelo Qui2 alto, podemos afirmar que há uma forte correlação.

# %%
# Avaliar a correlação entre uma variável qualitativa e quantitativa
# Usar o mesmo teste de Chi-Square, mas transformar a variável quantitativa em qualitativa
# Hipótese: Cliente com menos de 6 meses de contrato é mais propenso ao Churn

# Criar uma variável no Dataframe com base numa condição de outra coluna
# Coluna = 'TempoMenor6Meses'

import numpy as np

# %%
# Criar coluna nova 
df_churn['TempoMenor6Meses'] = np.where(df_churn.tenure < 6, 'Yes', 'No')

# %%
# Checar o Dataframe
df_churn.head()
# Out:
#     IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 0  7590-VHVEG  Female           0         Yes             No           No
# 1  5575-GNVDE    Male           0          No             No          Yes
# 2  3668-QPYBK    Male           0          No             No          Yes
# 3  7795-CFOCW    Male           0          No             No           No
# 4  9237-HQITU  Female           0          No             No          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies  tenure  \
# 0               No          No          No              No       1
# 1              Yes          No          No              No      34
# 2               No          No          No              No       2
# 3              Yes         Yes          No              No      45
# 4               No          No          No              No       2
#
#          Contract PaperlessBilling              PaymentMethod  \
# 0  Month-to-month              Yes           Electronic check
# 1        One year               No               Mailed check
# 2  Month-to-month              Yes               Mailed check
# 3        One year               No  Bank transfer (automatic)
# 4  Month-to-month              Yes           Electronic check
#
#       MonthlyCharges         TotalCharges Churn TempoMenor6Meses
# 0 29.850000000000001   29.850000000000001    No              Yes
# 1 56.950000000000003 1889.500000000000000    No               No
# 2 53.850000000000001  108.150000000000006   Yes              Yes
# 3 42.299999999999997 1840.750000000000000    No               No
# 4 70.700000000000003  151.650000000000006   Yes              Yes

# %%
# Gerar um DF da Crosstab (sem totais)
df_crosstab_churn_tenure = pd.crosstab(df_churn.Churn, df_churn.TempoMenor6Meses)

# %%
# Calcular os Scores
chi_scores_churn_tenure = chi2_contingency(df_crosstab_churn_tenure)

# %%
chi_scores_churn_tenure
# Out:
# Chi2ContingencyResult(statistic=669.7216158287102, pvalue=1.1485390172689518e-147, dof=1, expected_freq=array([[4166.82209286, 1007.17790714],
#        [1505.17790714,  363.82209286]]))

# %%
scores_churn_tenure = pd.Series(chi_scores_churn_tenure[0])
pvalues_churn_ternure = pd.Series(chi_scores_churn_tenure[1])

# %%
# Criar um Dataframe com os resultados
df_chi_scores_churn_tenure = pd.DataFrame(
    {
        'Qui2' : scores_churn_tenure, 
        'p-value' : pvalues_churn_ternure
    }
)

# %%
# Analisar os resultados
df_chi_scores_churn_tenure
# Out:
#                  Qui2           p-value
# 0 669.721615828710242 0.000000000000000

# %% [markdown]
# Como o p-value <= 0.05, rejeitamos a H0, ou seja, as variáveis não são independentes. E vale mencionar que com base no qui2 resultante das duas análises, a correlação entre churn e tempo de contrato < 6 meses é menor do que a correlação entre churn e tipo de contrato

# %%
# Correlação entre 2 variáveis numéricas
# Tenure com TotalCharges
# A intuição é que quanto mais tempo de contrato maior o valor pago.

# Correlção entre duas variáveis numéricas - Pearson
df_churn.tenure.corr(df_churn.TotalCharges)
# Out:
# 0.825880460933202

# %%
# Correlção entre duas variáveis numéricas - Spearman
df_churn.tenure.corr(df_churn.TotalCharges, method='spearman')
# Out:
# 0.8891770805365491

# %% [markdown]
# A uma forte correlação entre tenure e TotalCharges, usando métodos estatísticos de correlação.

# %%
# Apresentar Plot Scatter entre tenure e TotalCharges
# Gráfico de Dispersão
df_churn.plot.scatter(x='tenure', y='TotalCharges', figsize=(15, 6))
plt.show()

# %% [markdown]
# - Desafio 1: Validar a primeira hipótese de que a faixa etária do cliente tem uma forte associação com o churn.
# - Desafio 2: Validar com o teste de hipótese se contrato mensal está mais propenso ao churn.

# %%
# Desafio 1: Validar a primeira hipótese de que a faixa etária do cliente tem uma forte associação com o churn.
df_churn.head()
# Out:
#     IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 0  7590-VHVEG  Female           0         Yes             No           No
# 1  5575-GNVDE    Male           0          No             No          Yes
# 2  3668-QPYBK    Male           0          No             No          Yes
# 3  7795-CFOCW    Male           0          No             No           No
# 4  9237-HQITU  Female           0          No             No          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies  tenure  \
# 0               No          No          No              No       1
# 1              Yes          No          No              No      34
# 2               No          No          No              No       2
# 3              Yes         Yes          No              No      45
# 4               No          No          No              No       2
#
#          Contract PaperlessBilling              PaymentMethod  \
# 0  Month-to-month              Yes           Electronic check
# 1        One year               No               Mailed check
# 2  Month-to-month              Yes               Mailed check
# 3        One year               No  Bank transfer (automatic)
# 4  Month-to-month              Yes           Electronic check
#
#       MonthlyCharges         TotalCharges Churn TempoMenor6Meses
# 0 29.850000000000001   29.850000000000001    No              Yes
# 1 56.950000000000003 1889.500000000000000    No               No
# 2 53.850000000000001  108.150000000000006   Yes              Yes
# 3 42.299999999999997 1840.750000000000000    No               No
# 4 70.700000000000003  151.650000000000006   Yes              Yes

# %%
df_churn.Mais65anos.value_counts() # única variável correspondente à idade
# Out:
# Mais65anos
# 0    5901
# 1    1142
# Name: count, dtype: int64

# %%
# criando uma nova variável qualitativa baseada na idade
df_churn['acima_65_anos_qualitativa'] = np.where(df_churn.Mais65anos == 1, 'Yes', 'No')

# %%
df_churn.head()
# Out:
#     IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 0  7590-VHVEG  Female           0         Yes             No           No
# 1  5575-GNVDE    Male           0          No             No          Yes
# 2  3668-QPYBK    Male           0          No             No          Yes
# 3  7795-CFOCW    Male           0          No             No           No
# 4  9237-HQITU  Female           0          No             No          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies  tenure  \
# 0               No          No          No              No       1
# 1              Yes          No          No              No      34
# 2               No          No          No              No       2
# 3              Yes         Yes          No              No      45
# 4               No          No          No              No       2
#
#          Contract PaperlessBilling              PaymentMethod  \
# 0  Month-to-month              Yes           Electronic check
# 1        One year               No               Mailed check
# 2  Month-to-month              Yes               Mailed check
# 3        One year               No  Bank transfer (automatic)
# 4  Month-to-month              Yes           Electronic check
#
#       MonthlyCharges         TotalCharges Churn TempoMenor6Meses  \
# 0 29.850000000000001   29.850000000000001    No              Yes
# 1 56.950000000000003 1889.500000000000000    No               No
# 2 53.850000000000001  108.150000000000006   Yes              Yes
# 3 42.299999999999997 1840.750000000000000    No               No
# 4 70.700000000000003  151.650000000000006   Yes              Yes
#
#   acima_65_anos_qualitativa
# 0                        No
# 1                        No
# 2                        No
# 3                        No
# 4                        No

# %%
# Gerar um DF da Crosstab (sem totais)
df_crosstab_churn_idade = pd.crosstab(df_churn.Churn, df_churn.acima_65_anos_qualitativa)

# %%
# Calcular os Scores
chi_scores_churn_idade = chi2_contingency(df_crosstab_churn_idade)

# %%
chi_scores_churn_idade
# Out:
# Chi2ContingencyResult(statistic=159.42630036838742, pvalue=1.510066805092378e-36, dof=1, expected_freq=array([[4335.05239245,  838.94760755],
#        [1565.94760755,  303.05239245]]))

# %%
scores_churn_idade = pd.Series(chi_scores_churn_idade[0])
pvalues_churn_idade = pd.Series(chi_scores_churn_idade[1])

# %%
# Criar um Dataframe com os resultados
df_chi_scores_churn_tenure = pd.DataFrame(
    {
        'Qui2' : scores_churn_idade, 
        'p-value' : pvalues_churn_idade
    }
)

# %%
df_chi_scores_churn_tenure
# Out:
#                  Qui2           p-value
# 0 159.426300368387416 0.000000000000000

# %% [markdown]
# Como o p-value <= 0.05, rejeitamos a H0, ou seja, as variáveis não são independentes.

# %% [markdown]
# ## Detecção de Outliers (Valores Atípicos)

# %%
df_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   IDCliente                  7043 non-null   object
#  1   Genero                     7043 non-null   object
#  2   Mais65anos                 7043 non-null   int64
#  3   TemParceiro                7043 non-null   object
#  4   TemDependentes             7043 non-null   object
#  5   PhoneService               7043 non-null   object
#  6   MultipleLines              7043 non-null   object
#  7   InternetService            7043 non-null   object
#  8   OnlineSecurity             7043 non-null   object
#  9   OnlineBackup               7043 non-null   object
#  10  DeviceProtection           7043 non-null   object
#  11  TechSupport                7043 non-null   object
#  12  StreamingTV                7043 non-null   object
#  13  StreamingMovies            7043 non-null   object
#  14  tenure                     7043 non-null   int64
#  15  Contract                   7043 non-null   object
#  16  PaperlessBilling           7043 non-null   object
#  17  PaymentMethod              7043 non-null   object
#  18  MonthlyCharges             7043 non-null   float64
#  19  TotalCharges               7032 non-null   float64
#  20  Churn                      7043 non-null   object
#  21  TempoMenor6Meses           7043 non-null   object
#  22  acima_65_anos_qualitativa  7043 non-null   object
# dtypes: float64(2), int64(2), object(19)
# memory usage: 1.2+ MB

# %%
# Remover linhas com valores nulos
df_churn.dropna(axis=0, inplace=True)

# %%
# Box Plot Geral
df_churn['TotalCharges'].plot.box()
plt.plot(1, df_churn.TotalCharges.mean(), 'ro', label='média')
plt.legend()
plt.show()

# %%
# Box Plot agrupado por Contract
df_churn.plot.box(column='TotalCharges', by='Contract')
plt.show()

# %%
# Criar um Dataframe somente com clientes do tipo Month to Month (Contrato Mensal)
df_churn_month = df_churn[df_churn.Contract == 'Month-to-month']

# %%
df_churn_month.head()
# Out:
#     IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 0  7590-VHVEG  Female           0         Yes             No           No
# 2  3668-QPYBK    Male           0          No             No          Yes
# 4  9237-HQITU  Female           0          No             No          Yes
# 5  9305-CDSKC  Female           0          No             No          Yes
# 6  1452-KIOVK    Male           0          No            Yes          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 2                No             DSL            Yes          Yes
# 4                No     Fiber optic             No           No
# 5               Yes     Fiber optic             No           No
# 6               Yes     Fiber optic             No          Yes
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies  tenure  \
# 0               No          No          No              No       1
# 2               No          No          No              No       2
# 4               No          No          No              No       2
# 5              Yes          No         Yes             Yes       8
# 6               No          No         Yes              No      22
#
#          Contract PaperlessBilling            PaymentMethod  \
# 0  Month-to-month              Yes         Electronic check
# 2  Month-to-month              Yes             Mailed check
# 4  Month-to-month              Yes         Electronic check
# 5  Month-to-month              Yes         Electronic check
# 6  Month-to-month              Yes  Credit card (automatic)
#
#       MonthlyCharges         TotalCharges Churn TempoMenor6Meses  \
# 0 29.850000000000001   29.850000000000001    No              Yes
# 2 53.850000000000001  108.150000000000006   Yes              Yes
# 4 70.700000000000003  151.650000000000006   Yes              Yes
# 5 99.650000000000006  820.500000000000000   Yes               No
# 6 89.099999999999994 1949.400000000000091    No               No
#
#   acima_65_anos_qualitativa
# 0                        No
# 2                        No
# 4                        No
# 5                        No
# 6                        No

# %%
# Histograma - Checar visualmente se os dados seguem uma distribuição normal
df_churn_month.TotalCharges.plot.hist()
plt.show()

# %%
# Método de Tuckey - IQR (Distribuições não normal)
# IQR - Range Interquartil
# IQR = terceiro quartil - primeiro quartil
q1_TotalCharges_month = df_churn_month.TotalCharges.quantile(0.25)
q3_TotalCharges_month = df_churn_month.TotalCharges.quantile(0.75)
iqr_TotalCharges_month = q3_TotalCharges_month - q1_TotalCharges_month
iqr_TotalCharges_month
# Out:
# 1906.4

# %%
# Limites Inferior e Superior
limInf_TotalCharges_month = q1_TotalCharges_month - (iqr_TotalCharges_month * 1.5)
limSup_TotalCharges_month = q3_TotalCharges_month + (iqr_TotalCharges_month * 1.5)
limInf_TotalCharges_month, limSup_TotalCharges_month
# Out:
# (-2699.5000000000005, 4926.1)

# %%
df_churn_month[(df_churn_month.TotalCharges < limInf_TotalCharges_month) |
                (df_churn_month.TotalCharges > limSup_TotalCharges_month)]
# Out:
#        IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 13    0280-XJGEX    Male           0          No             No          Yes
# 61    1215-FIGMP    Male           0          No             No          Yes
# 93    6067-NGCEU  Female           0          No             No          Yes
# 110   0486-HECZI    Male           0         Yes             No          Yes
# 197   6168-YBYNP    Male           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 6897  2363-BJLSL    Male           0          No             No          Yes
# 6952  6394-MFYNG  Female           0          No             No          Yes
# 6965  7789-CRUVC  Female           1         Yes             No          Yes
# 7023  1035-IPQPU  Female           1         Yes             No          Yes
# 7034  0639-TSIQW  Female           0          No             No          Yes
#
#      MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 13             Yes     Fiber optic             No          Yes
# 61             Yes     Fiber optic             No          Yes
# 93             Yes     Fiber optic            Yes          Yes
# 110            Yes     Fiber optic            Yes          Yes
# 197            Yes     Fiber optic             No          Yes
# ...            ...             ...            ...          ...
# 6897            No             DSL             No          Yes
# 6952           Yes     Fiber optic             No          Yes
# 6965           Yes     Fiber optic            Yes          Yes
# 7023           Yes     Fiber optic             No          Yes
# 7034           Yes     Fiber optic            Yes          Yes
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies  tenure  \
# 13                Yes          No         Yes             Yes      49
# 61                 No          No         Yes              No      60
# 93                Yes          No         Yes             Yes      65
# 110                No          No         Yes              No      55
# 197               Yes         Yes         Yes             Yes      59
# ...               ...         ...         ...             ...     ...
# 6897              Yes         Yes         Yes             Yes      62
# 6952              Yes          No         Yes             Yes      48
# 6965              Yes         Yes          No              No      61
# 7023              Yes          No         Yes             Yes      63
# 7034              Yes          No         Yes              No      67
#
#             Contract PaperlessBilling              PaymentMethod  \
# 13    Month-to-month              Yes  Bank transfer (automatic)
# 61    Month-to-month              Yes  Bank transfer (automatic)
# 93    Month-to-month              Yes    Credit card (automatic)
# 110   Month-to-month              Yes           Electronic check
# 197   Month-to-month              Yes           Electronic check
# ...              ...              ...                        ...
# 6897  Month-to-month              Yes  Bank transfer (automatic)
# 6952  Month-to-month              Yes  Bank transfer (automatic)
# 6965  Month-to-month              Yes    Credit card (automatic)
# 7023  Month-to-month              Yes           Electronic check
# 7034  Month-to-month              Yes    Credit card (automatic)
#
#           MonthlyCharges         TotalCharges Churn TempoMenor6Meses  \
# 13   103.700000000000003 5036.300000000000182   Yes               No
# 61    89.900000000000006 5450.699999999999818    No               No
# 93   111.049999999999997 7107.000000000000000    No               No
# 110   96.750000000000000 5238.899999999999636   Yes               No
# 197  111.349999999999994 6519.750000000000000    No               No
# ...                  ...                  ...   ...              ...
# 6897  80.400000000000006 4981.149999999999636    No               No
# 6952 107.400000000000006 5121.300000000000182   Yes               No
# 6965  94.200000000000003 5895.449999999999818    No               No
# 7023 103.500000000000000 6479.399999999999636    No               No
# 7034 102.950000000000003 6886.250000000000000   Yes               No
#
#      acima_65_anos_qualitativa
# 13                          No
# 61                          No
# 93                          No
# 110                         No
# 197                         No
# ...                        ...
# 6897                        No
# 6952                        No
# 6965                       Yes
# 7023                       Yes
# 7034                        No
#
# [200 rows x 23 columns]

# %%
# Zscore (Usado para Distribuição Normal)
# Indica quantos desvios padrões um ponto específico de dados está distante da média
# Zscore = (x - média) / desvio padrão
from scipy.stats import zscore

# %%
z = np.abs(zscore(df_churn_month.TotalCharges))

# %%
z
# Out:
# 0      0.830035854105835
# 2      0.781512944511796
# 4      0.754555772515107
# 5      0.340066014124648
# 6      0.359519077072167
#               ...
# 7033   0.778346771186232
# 7034   3.418910216654943
# 7035   0.077987048610201
# 7040   0.633837218378213
# 7041   0.658532466747594
# Name: TotalCharges, Length: 3875, dtype: float64

# %%
df_churn_month[z > 3.0]
# Out:
#        IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 93    6067-NGCEU  Female           0          No             No          Yes
# 197   6168-YBYNP    Male           0          No             No          Yes
# 339   1343-EHPYB    Male           0         Yes             No          Yes
# 402   0979-PHULV    Male           0         Yes            Yes          Yes
# 445   7752-XUSCI  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 6565  1548-FEHVL    Male           0         Yes             No          Yes
# 6587  7426-GSWPO    Male           1          No             No          Yes
# 6713  4989-LIXVT    Male           1          No             No          Yes
# 7023  1035-IPQPU  Female           1         Yes             No          Yes
# 7034  0639-TSIQW  Female           0          No             No          Yes
#
#      MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 93             Yes     Fiber optic            Yes          Yes
# 197            Yes     Fiber optic             No          Yes
# 339            Yes     Fiber optic             No          Yes
# 402            Yes     Fiber optic             No           No
# 445            Yes     Fiber optic             No          Yes
# ...            ...             ...            ...          ...
# 6565           Yes     Fiber optic            Yes          Yes
# 6587           Yes     Fiber optic            Yes          Yes
# 6713           Yes     Fiber optic             No          Yes
# 7023           Yes     Fiber optic             No          Yes
# 7034           Yes     Fiber optic            Yes          Yes
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies  tenure  \
# 93                Yes          No         Yes             Yes      65
# 197               Yes         Yes         Yes             Yes      59
# 339               Yes          No         Yes             Yes      63
# 402               Yes          No         Yes             Yes      69
# 445               Yes          No         Yes             Yes      60
# ...               ...         ...         ...             ...     ...
# 6565               No          No         Yes             Yes      61
# 6587               No          No         Yes             Yes      64
# 6713              Yes          No          No             Yes      68
# 7023              Yes          No         Yes             Yes      63
# 7034              Yes          No         Yes              No      67
#
#             Contract PaperlessBilling              PaymentMethod  \
# 93    Month-to-month              Yes    Credit card (automatic)
# 197   Month-to-month              Yes           Electronic check
# 339   Month-to-month              Yes           Electronic check
# 402   Month-to-month              Yes    Credit card (automatic)
# 445   Month-to-month              Yes           Electronic check
# ...              ...              ...                        ...
# 6565  Month-to-month              Yes           Electronic check
# 6587  Month-to-month              Yes  Bank transfer (automatic)
# 6713  Month-to-month              Yes           Electronic check
# 7023  Month-to-month              Yes           Electronic check
# 7034  Month-to-month              Yes    Credit card (automatic)
#
#           MonthlyCharges         TotalCharges Churn TempoMenor6Meses  \
# 93   111.049999999999997 7107.000000000000000    No               No
# 197  111.349999999999994 6519.750000000000000    No               No
# 339  103.400000000000006 6603.000000000000000   Yes               No
# 402   99.450000000000003 7007.600000000000364   Yes               No
# 445  105.900000000000006 6396.449999999999818   Yes               No
# ...                  ...                  ...   ...              ...
# 6565 106.200000000000003 6375.199999999999818    No               No
# 6587 103.500000000000000 6548.649999999999636    No               No
# 6713  95.900000000000006 6503.199999999999818    No               No
# 7023 103.500000000000000 6479.399999999999636    No               No
# 7034 102.950000000000003 6886.250000000000000   Yes               No
#
#      acima_65_anos_qualitativa
# 93                          No
# 197                         No
# 339                         No
# 402                         No
# 445                         No
# ...                        ...
# 6565                        No
# 6587                       Yes
# 6713                       Yes
# 7023                       Yes
# 7034                        No
#
# [65 rows x 23 columns]

# %% [markdown]
# ## Automatizando EDA

# %%
# Sweetviz - Abrir no Jupyter Notebook
import sweetviz as sv
sv_churn_report = sv.analyze(df_churn, target_feat='Churn')

# %%
sv_churn_report.show_notebook()

# %%
# Sweetviz - HTML
sv_churn_report.show_html(filepath='./report_churn.html', open_browser=True, layout='widescreen')
